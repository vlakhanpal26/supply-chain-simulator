# %%
from simulator import simulate_inventory, plot_inventory
import matplotlib.pyplot as plt

# === EXPERIMENT 1 (your example numbers) ===
df = simulate_inventory(
    N=60,         # days
    mu=100,       # Step 2: mean demand
    sigma=20,     # Step 2: std dev
    initial_inventory=500,
    s=200,        # reorder point
    Q=500,        # order quantity
    L=3,          # lead time
    seed=42
)

df.head()
# Out:
#    Day  Inventory  Demand  OrdersPlaced  Deliveries
# 0    1        394     106             0           0
# 1    2        315      79             0           0
# 2    3        200     115           500           0
# 3    4         81     119           500           0
# 4    5         20      61           500           0

# %%
from simulator import plot_inventory
import matplotlib.pyplot as plt

plot_inventory(df)
plt.show()
